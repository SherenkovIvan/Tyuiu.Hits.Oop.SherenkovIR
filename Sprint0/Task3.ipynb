// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 8

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
//
// Создать базовый класс CreditCard в C#, который будет представлять информацию о кредитных картах. На основе этого класса разработать 2-3 производных класса, демонстрирующих принципы наследования и полиморфизма. В каждом из классов должны быть реализованы новые атрибуты и методы, а также переопределены некоторые методы базового класса для демонстрации полиморфизма.
//
// Требования к базовому классу CreditCard:
//
// • Атрибуты: Номер карты (CardNumber), Холдера (HolderName), Срок действия (ExpiryDate).
//
// • Методы:
//
// o GetInfo(): метод для получения информации о кредитной карте в виде строки.
//
// o Pay(): метод для оплаты покупки с использованием карты.
//
// o CheckBalance(): метод для проверки баланса на карте.
//
// Требования к производным классам:
//
// 1.GoldCard (GoldCreditCard): Должен содержать дополнительные атрибуты, такие как Бесплатные бонусные мили (BonusMiles). Метод Pay() должен быть переопределен для добавления информации о получении бонусных миль при оплате покупки.
//
// 2.PremiumCard (PremiumCreditCard): Должен содержать дополнительные атрибуты, такие как Ассистент поддержки (SupportAssistant). Метод CheckBalance() должен быть переопределен для предоставления возможности обратиться за помощью к ассистенту поддержки в случае проблем с балансом.
//
// 3.CorporateCard (CorporateCreditCard) (если требуется третий класс): Должен содержать дополнительные атрибуты, такие как Компания (Company). Метод GetInfo() должен быть переопределен для включения информации о компании в описании карты.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>

// %%
public interface ICreditCard
{
    string CardNumber { get; set; }
    string HolderName { get; set; }
    DateTime ExpiryDate { get; set; }
    
    string GetInfo();
    void Pay(decimal amount);
    void CheckBalance();
}

public interface IGoldCreditCard : ICreditCard
{
    int BonusMiles { get; set; }
}

public interface IPremiumCreditCard : ICreditCard
{
    string SupportAssistant { get; set; }
}

public interface ICorporateCreditCard : ICreditCard
{
    string Company { get; set; }
}

public class CreditCard : ICreditCard
{
    public string CardNumber { get; set; }
    public string HolderName { get; set; }
    public DateTime ExpiryDate { get; set; }

    public CreditCard(string cardNumber, string holderName, DateTime expiryDate)
    {
        CardNumber = cardNumber;
        HolderName = holderName;
        ExpiryDate = expiryDate;
    }

    public virtual string GetInfo() => $"Карта: {CardNumber}, Владелец: {HolderName}, Срок: {ExpiryDate:MM/yy}";

    public virtual void Pay(decimal amount) => Console.WriteLine(amount <= 0 ? "Сумма должна быть больше 0" : $"Оплачено: {amount:F2} руб.");

    public virtual void CheckBalance() => Console.WriteLine($"Проверка баланса карты {CardNumber}\nСрок действия: {ExpiryDate:MM/yy}");
}

public class GoldCreditCard : CreditCard, IGoldCreditCard
{
    public int BonusMiles { get; set; }

    public GoldCreditCard(string cardNumber, string holderName, DateTime expiryDate, int bonusMiles)
        : base(cardNumber, holderName, expiryDate) => BonusMiles = bonusMiles;

    public override void Pay(decimal amount)
    {
        if (amount <= 0) Console.WriteLine("Сумма должна быть больше 0");
        else
        {
            int miles = (int)(amount / 100);
            BonusMiles += miles;
            Console.WriteLine($"Оплачено: {amount:F2} руб. Начислено миль: {miles}. Всего миль: {BonusMiles}.");
        }
    }

    public override string GetInfo() => base.GetInfo() + $", Мили: {BonusMiles}";
}

public class PremiumCreditCard : CreditCard, IPremiumCreditCard
{
    public string SupportAssistant { get; set; }

    public PremiumCreditCard(string cardNumber, string holderName, DateTime expiryDate, string supportAssistant)
        : base(cardNumber, holderName, expiryDate) => SupportAssistant = supportAssistant;

    public override void CheckBalance()
    {
        base.CheckBalance();
        Console.WriteLine($"Персональный ассистент: {SupportAssistant}\nЕсли у вас проблемы с балансом, обратитесь к ассистенту!");
    }

    public override string GetInfo() => base.GetInfo() + $", Ассистент: {SupportAssistant}";
}

public class CorporateCreditCard : CreditCard, ICorporateCreditCard
{
    public string Company { get; set; }

    public CorporateCreditCard(string cardNumber, string holderName, DateTime expiryDate, string company)
        : base(cardNumber, holderName, expiryDate) => Company = company;

    public override string GetInfo() => $"КОРПОРАТИВНАЯ КАРТА\nКомпания: {Company}\n{base.GetInfo()}";

    public override void Pay(decimal amount) => Console.WriteLine(amount <= 0 ? "Сумма должна быть больше 0" : $"Корпоративный платеж от {Company}: {amount:F2} руб.");
}

// Тестирование
var cards = new ICreditCard[]
{
    new CreditCard("1212-2121-3443-5445", "Иван Анатольевич", new DateTime(2026, 12, 31)),
    new GoldCreditCard("5555-6666-7777-8888", "Пелогея Иванова", new DateTime(2025, 6, 30), 100),
    new PremiumCreditCard("9173-8888-7647-6568", "Александр Петров", new DateTime(2027, 3, 15), "Мария Соколова"),
    new CorporateCreditCard("7128-3393-2221-3211", "Сергей Смирнов", new DateTime(2024, 9, 30), "ООО Веники Иваныча")
};

Console.WriteLine("=== ИНФОРМАЦИЯ О КАРТАХ ===");
foreach (var card in cards) Console.WriteLine(card.GetInfo() + "\n");

Console.WriteLine("=== ПРОВЕРКА БАЛАНСА ===");
foreach (var card in cards) { card.CheckBalance(); Console.WriteLine(); }

Console.WriteLine("=== ОПЛАТА ПОКУПОК ===");
string[] names = { "Обычная карта", "Золотая карта", "Премиум карта", "Корпоративная карта" };
decimal[] amounts = { 1200m, 2500m, 3000m, 15000m };
for (int i = 0; i < cards.Length; i++)
{
    Console.WriteLine($"{names[i]}:");
    cards[i].Pay(amounts[i]);
    Console.WriteLine();
}

Console.WriteLine("=== ПОПЫТКА ОПЛАТЫ СВЕРХ БАЛАНСА ===");
cards[0].Pay(5000m);
Console.WriteLine();

Console.WriteLine("=== ПОЛИМОРФИЗМ ===");
foreach (var card in cards)
{
    Console.WriteLine($"Вызов Pay(300) для {card.GetType().Name}:");
    card.Pay(300m);
    Console.WriteLine();
}

Console.WriteLine("=== ИТОГОВАЯ ИНФОРМАЦИЯ ===");
foreach (var card in cards) Console.WriteLine(card.GetInfo() + "\n");
// Out:
// === ИНФОРМАЦИЯ О КАРТАХ ===
// Карта: 1212-2121-3443-5445, Владелец: Иван Анатольевич, Срок: 12/26
//
// Карта: 5555-6666-7777-8888, Владелец: Пелогея Иванова, Срок: 06/25, Мили: 100
//
// Карта: 9173-8888-7647-6568, Владелец: Александр Петров, Срок: 03/27, Ассистент: Мария Соколова
//
// КОРПОРАТИВНАЯ КАРТА
// Компания: ООО Веники Иваныча
// Карта: 7128-3393-2221-3211, Владелец: Сергей Смирнов, Срок: 09/24
//
// === ПРОВЕРКА БАЛАНСА ===
// Проверка баланса карты 1212-2121-3443-5445
// Срок действия: 12/26
//
// Проверка баланса карты 5555-6666-7777-8888
// Срок действия: 06/25
//
// Проверка баланса карты 9173-8888-7647-6568
// Срок действия: 03/27
// Персональный ассистент: Мария Соколова
// Если у вас проблемы с балансом, обратитесь к ассистенту!
//
// Проверка баланса карты 7128-3393-2221-3211
// Срок действия: 09/24
//
// === ОПЛАТА ПОКУПОК ===
// Обычная карта:
// Оплачено: 1200.00 руб.
//
// Золотая карта:
// Оплачено: 2500.00 руб. Начислено миль: 25. Всего миль: 125.
//
// Премиум карта:
// Оплачено: 3000.00 руб.
//
// Корпоративная карта:
// Корпоративный платеж от ООО Веники Иваныча: 15000.00 руб.
//
// === ПОПЫТКА ОПЛАТЫ СВЕРХ БАЛАНСА ===
// Оплачено: 5000.00 руб.
//
// === ПОЛИМОРФИЗМ ===
// Вызов Pay(300) для CreditCard:
// Оплачено: 300.00 руб.
//
// Вызов Pay(300) для GoldCreditCard:
// Оплачено: 300.00 руб. Начислено миль: 3. Всего миль: 128.
//
// Вызов Pay(300) для PremiumCreditCard:
// Оплачено: 300.00 руб.
//
// Вызов Pay(300) для CorporateCreditCard:
// Корпоративный платеж от ООО Веники Иваныча: 300.00 руб.
//
// === ИТОГОВАЯ ИНФОРМАЦИЯ ===
// Карта: 1212-2121-3443-5445, Владелец: Иван Анатольевич, Срок: 12/26
//
// Карта: 5555-6666-7777-8888, Владелец: Пелогея Иванова, Срок: 06/25, Мили: 128
//
// Карта: 9173-8888-7647-6568, Владелец: Александр Петров, Срок: 03/27, Ассистент: Мария Соколова
//
// КОРПОРАТИВНАЯ КАРТА
// Компания: ООО Веники Иваныча
// Карта: 7128-3393-2221-3211, Владелец: Сергей Смирнов, Срок: 09/24
